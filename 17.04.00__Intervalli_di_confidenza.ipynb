# %% [markdown]
# # Intervalli di confidenza
#
# Finora abbiamo visto due metodi approssimati per stimare gli intervalli di incertezza delle stime di massima verosimiglianza:
# * nell'approssimazione parabolica di $-2\log{\cal L}(x;\theta)$, l'errore si può stimare come:
#
# $\displaystyle \frac{1}{\sigma_{\hat{\theta}}^2} = -\left.\frac{\partial^2\log{\cal L}(x;\theta)}{\partial\theta^2}\right|_{\theta=\hat{\theta}}$
#
# * si considera lo scan della curva $-2\log{\cal L}(x;\theta)$ in funzione di $\theta$ e si trovano i valori estremi per i quali:
#
# $-2\log{\cal L}(x;\theta) = -2\log{\cal L}(x;\hat{\theta}) + 1$
#
# Esiste anche una procedura più rigorosa, ma più complessa, rispetto alle due approssimazioni di cui sopra per trovare un'intervallo che rappresenta l'incertezza sulla stima di un parametro.
#
# Come vedremo, gli aspetti tecnici possono essere non banali, per questo le stime approssimate, anche se meno rigorose, sono di uso più frequente.

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import gamma
from scipy.optimize import fsolve
from scipy.optimize import fmin
from scipy.optimize import bisect
from scipy.interpolate import interp1d

# %% [markdown]
# Consideriamo una distribuzione normale con $\sigma$ noto e $\mu$ ignoto. Se misuriamo $x=x^\star$, l'intervallo di incertezza per $\mu$ viene riportato com come $[x^\star - \sigma, x^\star + \sigma]$.
#
# Possiamo immaginare di costruire questa stima nel modo seguente:
#
# 1. al variare del valore vero $\mu$, viene calcolato l'intervallo centrale corrispondente al 68.27% di probabilità, ossia $[\mu - \sigma, \mu + \sigma]$.
# 1. l'insieme di tutti gli intervalli determina nel piano $(x^\star,\mu)$ una fascia di confidenza (*confidence band* o *confidence belt* in inglese);
# 1. dato il valore osservato $x=x^\star$, si può *invertire* la fascia di condidenza trovando l'intersezione con la retta verticale corrispondente a $x=x^\star$;
# 1. l'intersezione viene riportata come intervallo di confidenza per $\mu$. In questo caso, l'intevallo è $[x^\star - \sigma, x^\star + \sigma]$.
#
# Questo metodo è generalizzabile a PDF meno regolari del caso normale che abbiamo esaminato.

# %%
plt.figure(figsize=(6,6))
plt.xlabel(r'$x$')
plt.ylabel(r'$\mu$')
plt.plot([0, 6], [0, 6], color='red')
plt.plot([0, 5], [1, 6], color='blue')
plt.plot([1, 6], [0, 5], color='blue')
mu_0 = x_hat = 3.5
x_lo, x_hi = mu_0 - 1, mu_0 + 1
plt.plot([0, x_lo], [mu_0, mu_0], color='orange', linestyle='--')
plt.plot([x_lo, x_hi], [mu_0, mu_0], color='red', linestyle='--')
plt.plot([x_hi, x_hi], [0, mu_0], color='orange', linestyle='--')
plt.plot([x_lo, x_lo], [0, mu_0], color='orange', linestyle='--')
plt.plot([x_hat, x_hat], [0, mu_0], color='orange', linestyle='--')
plt.ylim(0, 6)
plt.xlim(0, 6)
plt.show()

# %%
plt.figure(figsize=(6,6), dpi=120)
plt.xlabel(r'$x^\star$')
plt.ylabel(r'$\mu$')
plt.plot([0, 6], [0, 6], color='red')
plt.plot([0, 5], [1, 6], color='blue')
plt.plot([1, 6], [0, 5], color='blue')
x_obs = mu_hat = 3.5
mu_lo, mu_hi = mu_hat - 1, mu_hat + 1
plt.plot([x_obs, x_obs], [0, mu_lo], color='orange', linestyle='--')
plt.plot([x_obs, x_obs], [mu_lo, mu_hi], color='red', linestyle='--')
plt.plot([0, x_obs], [mu_hat, mu_hat], color='orange', linestyle='--')
plt.plot([0, x_obs], [mu_lo, mu_lo], color='orange', linestyle='--')
plt.plot([0, x_obs], [mu_hi, mu_hi], color='orange', linestyle='--')
plt.ylim(0, 6)
plt.xlim(0, 6)
plt.show()

# %% [markdown]
# ## Neyman belt
#
# Se questa procedura è ovvia per una distribuzione gaussiana, ci sono aspetti non scontati nel trattamento di una distribuzione generica.
#
# In generale, si tratta di trovate per ciascun valore del parametro incognito un intervallo che corrisponde alla probabilità voluta (es.: 68% o 90%, ecc.), e poi invertire la fascia così ottenuta, che prende il nome di *Neyman belt*.
#
# La figura che segue è tratta dal [PDG, The Review of Particle Physics](https://pdg.lbl.gov/):
#
# <img style="width: 500px" src="img/neyman-belt-pdg.png">

# %% [markdown]
# Immaginiamo di stimare il parametro di scala $\theta$ di una distribuzione gamma:
#
# $\displaystyle f(x;\kappa,\theta) = \frac{x^{\kappa-1}e^{-x/\theta}}{\theta^\kappa\,\Gamma(\kappa)}$
#
# Supponiamo che il parametro $\kappa$ sia noto, ad es.: $\kappa=3$.
#
# La *moda* risulta, come abbiamo visto già in precedenza:
#
# $x^{\mathrm{max}} = \theta\,(\kappa-1)$
#
# Se abbiamo quindi un'osservazione $x$, la stima di massima verosimiglianza di $\theta$ si ottiene ponendo $x=x^\star$, ossia:
#
# $\displaystyle \hat{\theta}=\frac{x^\star}{\kappa-1}$

# %%
xrange=(0, 30)
x = np.linspace(xrange[0], xrange[1], 100)
k = 3
theta=2.5
model = gamma(k, scale=theta)
y = model.pdf(x)
mode = fmin(lambda x: -model.pdf(x), 1, disp=0)[0]
plt.figure(figsize=(8,5), dpi=120)
plt.plot(x,y)
plt.ylim(bottom=0)
plt.plot([mode,mode], [0, model.pdf(mode)], label='mode', linestyle='--')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.show()

# %% [markdown]
# Calcoliamo ora un intervallo che corrisponde ad una probabilità del 68.27%.
#
# <span style="color:blue">Fissato il **livello di confidenza** (*confidence level* o **CL** in inglese), esistono più modi per scegliere un untervallo corrispondente alla probabilità voluta.
# Ad esempio, possiamo scegliere code simmetriche con aree uguali. Ma non è l'unica scelta possibile.</span>

# %%
cl = .6827
def interval_sym_tails(theta):
    p_lo = (1 - cl)/2
    p_hi = 1 - p_lo
    if theta == 0: return 0, 0, 0, 0
    else:
        model = gamma(k, scale=theta)
        x_hat = fmin(lambda x: -model.pdf(x), 1, disp=0)[0]
        x_lo = fsolve(lambda x: model.cdf(x) - p_lo, 0)[0]
        x_hi = fsolve(lambda x: model.cdf(x) - p_hi, 1)[0]
        return theta, x_hat, x_lo, x_hi
theta, x_hat, x_lo, x_hi = interval_sym_tails(theta)
print("par = {:.2f}; [{:.2f}, {:.2f}]".format(theta, x_lo, x_hi))
x_ab = np.linspace(x_lo, x_hi, 100)
y_ab = model.pdf(x_ab)
plt.figure(figsize=(8,5), dpi=120)
plt.plot(x,y)
plt.ylim(bottom=0)
plt.plot([mode,mode], [0, gamma.pdf(mode, k, scale=theta)], label='mode', linestyle='--')
plt.fill_between(x_ab, y_ab, alpha=0.2)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.show()
# Out:
# par = 2.50; [3.42, 11.59]

# %% [markdown]
# Calcoliamo la **banda di confidenza** al 68% di **livello di confidenza** (CL).
#
# Visto che abbiamo modificato solo il parametro di scala, è naturale che la banda di confidenza sia uno "spicchio" nel piano $(\hat{x}, \theta)$.

# %%
band = np.array([interval_sym_tails(theta) for theta in np.linspace(0.05, 2.0, 100)])

# %%
def plot_band(theta_0, par_name):
    theta, x_hat, x_lo, x_hi = band[:, 0], band[:, 1], band[:, 2], band[:, 3]
    x_band_lo = interp1d(theta, x_lo)
    x_band_hi = interp1d(theta, x_hi)
    x_band_hat = interp1d(theta, x_hat)
    x_lo_0, x_hat_0, x_hi_0 = x_band_lo(theta_0), x_band_hat(theta_0), x_band_hi(theta_0)
    print("x interval: [{:.2f}, {:.2f}] at 68% CL".format(x_lo_0, x_hi_0))
    plt.figure(figsize=(6,6), dpi=120)
    plt.plot(x_hat, theta, linestyle='-', color='r')
    plt.plot(x_lo, theta, color='b', linewidth=2)
    plt.plot(x_hi, theta, color='b', linewidth=2)
    plt.plot([0, x_lo_0], [theta_0, theta_0], color='orange', linestyle='--')
    plt.plot([x_lo_0, x_hi_0], [theta_0, theta_0], color='red', linestyle='--')
    plt.plot([x_hi_0, x_hi_0], [0, theta_0], color='orange', linestyle='--')
    plt.plot([x_lo_0, x_lo_0], [0, theta_0], color='orange', linestyle='--')
    plt.plot([x_hat_0, x_hat_0], [0, theta_0], color='orange', linestyle='--')
    plt.xlabel(r'$x^\star$')
    plt.ylabel(par_name)
    plt.ylim(0, theta.max())
    plt.xlim(0, x_hi.max())
    plt.show()

# %%
plot_band(1, r'$\theta$')
# Out:
# x interval: [1.37, 4.64] at 68% CL

# %% [markdown]
# Possiamo costruire l'**intervallo di confidenza** al 68% CL invertendo la banda di confidenza:

# %%
def plot_band_inv(x_obs, par_name):
    theta, x_hat, x_lo, x_hi = band[:, 0], band[:, 1], band[:, 2], band[:, 3]
    theta_band_lo = interp1d(x_lo, theta)
    theta_band_hi = interp1d(x_hi, theta)
    theta_band_hat = interp1d(x_hat, theta)
    # notare l'inversione tra lo e hi:
    theta_lo, theta_hi = theta_band_hi(x_obs), theta_band_lo(x_obs)
    theta_hat = theta_band_hat(x_obs)
    err_lo, err_hi = theta_hat - theta_lo, theta_hi - theta_hat
    print("par interval: [{:.2f}, {:.2f}] at 68% CL".format(theta_lo, theta_hi))
    print("par = {:.2f} +{:.2f}/-{:.2f}".format(theta_hat, err_lo, err_hi))
    plt.figure(figsize=(6,6), dpi=120)
    plt.plot(x_hat, theta, linestyle='-', color='r')
    plt.plot(x_lo, theta, color='b', linewidth=2)
    plt.plot(x_hi, theta, color='b', linewidth=2)
    plt.plot([x_obs, x_obs], [0, theta_lo], color='orange', linestyle='--')
    plt.plot([x_obs, x_obs], [theta_lo, theta_hi], color='red', linestyle='--')
    plt.plot([0, x_obs], [theta_hat, theta_hat], color='orange', linestyle='--')
    plt.plot([0, x_obs], [theta_lo, theta_lo], color='orange', linestyle='--')
    plt.plot([0, x_obs], [theta_hi, theta_hi], color='orange', linestyle='--')
    plt.xlabel(r'$x^\star$')
    plt.ylabel(par_name)
    plt.ylim(0, theta.max())
    plt.xlim(0, x_hi.max())
    plt.show()

# %%
plot_band_inv(2.2, r'$\theta$')
# Out:
# par interval: [0.47, 1.61] at 68% CL
# par = 1.10 +0.63/-0.51

# %% [markdown]
# ## *Coverage*
#
# Per costruzione la probabilità che l'intervallo *copra* il valore vero è il 68%, per costruzione della banda di confidenza. Questa proprietà prende il nome, in inglese, di **coverage**.

# %% [markdown]
# # Spunti per esercizi
#
# * Ripetere il calcolo dell'intervallo di confidenza per una PDF che segua la distribuzione *beta* data da:
#
# $\displaystyle f(x; \alpha, \beta) = \frac{x^{\alpha-1}(1-x)^{\beta-1}}{B(\alpha,\beta)}$
#
# Il parametro $\beta$ è vincolato ad essere pari a $\theta-\alpha$, con $\theta$ fissato (es.: $\theta=10$) in modo che ci sia un solo parametro da determinare ($\alpha$).
#
# $\displaystyle f(x; \alpha) = \frac{x^{\alpha-1}(1-x)^{\theta-\alpha-1}}{B(\alpha,\theta-\alpha)}$
#
#
# Si può usare l'impementazione [```beta```](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.beta.html) di ```scipy```.

# %% [markdown]
# Innanzitutto, grafichiamo le distribuzioni.

# %%
from scipy.stats import beta
x = np.linspace(0, 1, 100)
theta = 10
plt.figure(figsize=(8,7), dpi=100)
colormap =plt.get_cmap('seismic')
a_range = np.linspace(0.5, theta - 0.5, 19)
colors = np.linspace(0, 1, len(a_range)+1)
for a, c in zip(a_range, colors):
    b = theta - a
    model = beta(a, b)
    y = model.pdf(x)
    plt.plot(x,y,label=r"$\alpha={:.2f}$".format(a), color=colormap(c))
plt.ylim(bottom=0)
plt.xlabel('$x$')
plt.ylabel(r'$f(x)=\beta(x;\alpha, \theta-\alpha)$')
plt.legend(ncol=2)
plt.show()

# %% [markdown]
# Definiamo due due code, destra e sinistra, di uguale probabilità.

# %%
def interval_sym_tails(alpha):
    p_lo = (1 - cl)/2
    p_hi = 1 - p_lo
    model = beta(alpha, 10 - alpha)
    x_hat = fmin(lambda x: -model.pdf(x), 0.5, disp=0)[0]
    x_lo = fsolve(lambda x: model.cdf(x) - p_lo, 0.02)[0]
    x_hi = fsolve(lambda x: model.cdf(x) - p_hi, 0.98)[0]
    return alpha, x_hat, x_lo, x_hi

# %%
band = np.array([interval_sym_tails(alpha) for alpha in np.linspace(0.5, 9.5, 100)])

# %%
band=np.insert(np.append(band, [[10, 1, 1, 1]], axis=0), 0, [[0, 0, 0, 0,]], axis=0)

# %%
alpha, x_hat, x_lo, x_hi = band[:, 0], band[:, 1], band[:, 2], band[:, 3]

# %%
plot_band(3, r'$\alpha$')
# Out:
# x interval: [0.16, 0.44] at 68% CL

# %% [markdown]
# <span style="color: red">Si noti che, per alcuni valori, il valore più probabile è *fuori* dall'intervallo al 68%!</span>
#
# È chiaro che la definizione di intervallo con code di area simmetrica non si adatta a questo modello di PDF.

# %% [markdown]
# Proviamo ad implementare un il metodo con un intervallo di minima larghezza, ossia quello per il quale la PDF ha lo stesso valore per entrambi gli estremi, come abbiamo dimostrato a suo tempo.
#
# Questa implementazione risulterà numericamente abbastanza più lenta.

# %%
def interval_shortest(alpha):
    model = beta(alpha, 10-alpha)
    if alpha<=1: x_hat = 0
    elif alpha>=9: x_hat = 1
    else: x_hat = fmin(lambda x: -model.pdf(x), 0.5, disp=0)[0]
    def int_area(h):
        if alpha<=1: x_lo = 0
        else: x_lo = bisect(lambda x: model.pdf(x) - h, 0, x_hat)
        if alpha>=9: x_hi = 1
        else: x_hi = bisect(lambda x: model.pdf(x) - h, x_hat, 1)
        return x_lo, x_hi, model.cdf(x_hi) - model.cdf(x_lo)
    if alpha<1 or alpha>9: mm = 10
    else: mm = model.pdf(x_hat)
    h = bisect(lambda h: int_area(h)[2]-0.6827, 0, mm)
    x_lo, x_hi, a = int_area(h)
    print("α = {:.2f} : {:.3f}, [{:.3f}, {:.3f}]".format(alpha, x_hat, x_lo, x_hi))
    return alpha, x_hat, x_lo, x_hi

# %%
band = np.array([interval_shortest(alpha) for alpha in np.linspace(0.5, 9.5, 46)])
# Out:
# α = 0.50 : 0.000, [0.000, 0.053]
# α = 0.70 : 0.000, [0.000, 0.080]
# α = 0.90 : 0.000, [0.000, 0.107]
# α = 1.10 : 0.012, [0.000, 0.133]
# α = 1.30 : 0.037, [0.002, 0.159]
# α = 1.50 : 0.062, [0.009, 0.189]
# α = 1.70 : 0.087, [0.021, 0.219]
# α = 1.90 : 0.112, [0.034, 0.250]
# α = 2.10 : 0.137, [0.049, 0.279]
# α = 2.30 : 0.162, [0.065, 0.309]
# α = 2.50 : 0.187, [0.082, 0.337]
# α = 2.70 : 0.212, [0.100, 0.365]
# α = 2.90 : 0.237, [0.119, 0.393]
# α = 3.10 : 0.262, [0.138, 0.420]
# α = 3.30 : 0.287, [0.158, 0.447]
# α = 3.50 : 0.312, [0.178, 0.473]
# α = 3.70 : 0.337, [0.198, 0.499]
# α = 3.90 : 0.362, [0.219, 0.524]
# α = 4.10 : 0.387, [0.241, 0.549]
# α = 4.30 : 0.412, [0.263, 0.574]
# α = 4.50 : 0.437, [0.285, 0.599]
# α = 4.70 : 0.462, [0.308, 0.623]
# α = 4.90 : 0.487, [0.330, 0.646]
# α = 5.10 : 0.512, [0.354, 0.670]
# α = 5.30 : 0.538, [0.377, 0.692]
# α = 5.50 : 0.562, [0.401, 0.715]
# α = 5.70 : 0.588, [0.426, 0.737]
# α = 5.90 : 0.613, [0.451, 0.759]
# α = 6.10 : 0.638, [0.476, 0.781]
# α = 6.30 : 0.663, [0.501, 0.802]
# α = 6.50 : 0.688, [0.527, 0.822]
# α = 6.70 : 0.713, [0.553, 0.842]
# α = 6.90 : 0.738, [0.580, 0.862]
# α = 7.10 : 0.763, [0.607, 0.881]
# α = 7.30 : 0.788, [0.635, 0.900]
# α = 7.50 : 0.813, [0.663, 0.918]
# α = 7.70 : 0.838, [0.691, 0.935]
# α = 7.90 : 0.863, [0.721, 0.951]
# α = 8.10 : 0.888, [0.750, 0.966]
# α = 8.30 : 0.913, [0.781, 0.979]
# α = 8.50 : 0.938, [0.811, 0.991]
# α = 8.70 : 0.963, [0.841, 0.998]
# α = 8.90 : 0.988, [0.867, 1.000]
# α = 9.10 : 1.000, [0.893, 1.000]
# α = 9.30 : 1.000, [0.920, 1.000]
# α = 9.50 : 1.000, [0.947, 1.000]

# %%
band=np.insert(np.append(band, [[10, 1, 1, 1]], axis=0), 0, [[0, 0, 0, 0]], axis=0)

# %%
alpha, x_hat, x_lo, x_hi = band[:, 0], band[:, 1], band[:, 2], band[:, 3]

# %%
plot_band(4, r'$\alpha$')
# Out:
# x interval: [0.23, 0.54] at 68% CL

# %%
plot_band_inv(0.3, r'$\alpha$')
# Out:
# par interval: [2.24, 4.63] at 68% CL
# par = 3.40 +1.16/-1.23

# %% [markdown]
# In questo caso, il valore più probabile, $\hat{x}$, sarà sempre contenuto all'interno dell'intervallo al 68% di probabilità. Quindi il valore centrale $\hat{\alpha}$ sarà anch'esso contenuto nell'intervallo di confidenza che si ottiene "invertendo" la bannda di confidenza costruita col metodo descritto sopra.
#
# Va notato che, per $\alpha<1$ e per $\alpha>9$, l'intervallo è completamente asimmetrico, ossia parte dall'estremo sinistro $x=0$ per $\alpha<1$ e arriva a quello destro $x=1$ per $\alpha>9$.
